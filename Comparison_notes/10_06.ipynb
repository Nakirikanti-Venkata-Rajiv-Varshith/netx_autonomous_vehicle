# %% [markdown]
# # ALB

# %% [markdown]
# ### 1. NORMAL CASES
#
#
# Array 1: Average Resource Utilization
# [70.98, 72.74, 16.05, 60.43, 4651.70]
#
# Array 2: FPS
# [10.06]
#
# Array 3: Overall E2E Latencies
# [46.20, 96.90, 166.01]
#
# Array 4: lane_detection E2E Latencies
# [23.80, 58.50, 125.49]
#
# Array 5: collision_avoidance E2E Latencies
# [29.70, 59.30, 127.19]
#
# Array 6: traffic_sign_detection E2E Latencies
# [82.10, 119.50, 193.46]
#
# Array 7: Onboard Count per Application
# [1092, 1091, 0]
#
# Array 8: Offload Count per Application
# [573, 573, 1661]
#
# Array 9:
# [1665, 4990, 5]
#
#
# ### 2. Under Stress Varying
#
# Array 1: Average Resource Utilization
# [91.07, 90.55, 70.70, 88.04, 9307.19]
#
# Array 2: FPS
# [9.12]
#
# Array 3: Overall E2E Latencies
# [97.40, 186.92, 692.08]
#
# Array 4: lane_detection E2E Latencies
# [96.60, 181.80, 690.50]
#
# Array 5: collision_avoidance E2E Latencies
# [97.10, 184.00, 690.91]
#
# Array 6: traffic_sign_detection E2E Latencies
# [98.30, 197.80, 691.23]
#
# Array 7: Onboard Count per Application
# [66, 66, 0]
#
# Array 8: Offload Count per Application
# [1630, 1630, 1695]
#
# Array 9:
# [1696, 1695, 1]

# %% [markdown]
# # ONBOARD

# %% [markdown]
# ### 1. Normal Cases
#
# Array 1: Average Resource Utilization
# [79.37, 67.46, 22.46, 62.98, 5277.75]
#
# Array 2: FPS
# [9.99]
#
# Array 3: Overall E2E Latencies
# [24.80, 41.40, 103.92]
#
# Array 4: lane_detection E2E Latencies
# [19.30, 30.80, 93.50]
#
# Array 5: collision_avoidance E2E Latencies
# [24.45, 38.64, 102.54]
#
# Array 6: traffic_sign_detection E2E Latencies
# [30.00, 47.00, 111.78]
#
# Array 7: Onboard Count per Application
# [1681, 1680, 1680]
#
# Array 8: Offload Count per Application
# [0, 0, 0]
#
# Array 9: Frame Statistics
# [1681, 1680, 1]
#
#
#
# ### 2. Under Stress Varying
# Array 1: Average Resource Utilization
# [94.99, 87.53, 4.05, 18.79, 5346.82]
#
# Array 2: FPS
# [3.68]
#
# Array 3: Overall E2E Latencies
# [47.50, 250.90, 4764.81]
#
# Array 4: lane_detection E2E Latencies
# [36.40, 228.54, 4760.17]
#
# Array 5: collision_avoidance E2E Latencies
# [46.60, 244.36, 4763.07]
#
# Array 6: traffic_sign_detection E2E Latencies
# [58.50, 276.64, 4773.98]
#
# Array 7: Onboard Count per Application
# [663, 663, 663]
#
# Array 8: Offload Count per Application
# [0, 0, 0]
#
# Array 9:
# [663, 663, 0]
#
#
# ### Under Stress Constat External 85%
#
# Array 1: Average Resource Utilization
# [91.95, 77.28, 6.27, 20.74, 5012.43]
#
# Array 2: FPS
# [2.28]
#
# Array 3: Overall E2E Latencies
# [32.40, 105.70, 2806.06]
#
# Array 4: lane_detection E2E Latencies
# [25.85, 91.43, 2694.35]
#
# Array 5: collision_avoidance E2E Latencies
# [31.00, 106.06, 2775.99]
#
# Array 6: traffic_sign_detection E2E Latencies
# [42.80, 115.38, 2785.89]
#
# Array 7: Onboard Count per Application
# [410, 410, 410]
#
# Array 8: Offload Count per Application
# [0, 0, 0]
#
# Array 9:
# [410, 410, 0]
#
#
# ### Under Stress Constant 80%
#
# Array 1: Average Resource Utilization
# [91.30, 83.73, 4.41, 15.57, 5180.28]
#
# Array 2: FPS
# [3.43]
#
# Array 3: Overall E2E Latencies
# [38.90, 171.60, 3183.20]
#
# Array 4: lane_detection E2E Latencies
# [30.10, 161.02, 3150.36]
#
# Array 5: collision_avoidance E2E Latencies
# [37.10, 166.04, 3156.26]
#
# Array 6: traffic_sign_detection E2E Latencies
# [47.40, 190.38, 3160.31]
#
# Array 7: Onboard Count per Application
# [617, 617, 617]
#
# Array 8: Offload Count per Application
# [0, 0, 0]
#
# Array 9:
# [617, 617, 0]
#
#
# ### Understress constant 75%
#
# Array 1: Average Resource Utilization
# [89.88, 83.98, 6.51, 24.44, 5217.28]
#
# Array 2: FPS
# [3.48]
#
# Array 3: Overall E2E Latencies
# [37.30, 203.70, 2113.42]
#
# Array 4: lane_detection E2E Latencies
# [30.00, 175.18, 2072.66]
#
# Array 5: collision_avoidance E2E Latencies
# [36.90, 201.54, 2085.74]
#
# Array 6: traffic_sign_detection E2E Latencies
# [46.70, 222.98, 2094.59]
#
# Array 7: Onboard Count per Application
# [627, 627, 627]
#
# Array 8: Offload Count per Application
# [0, 0, 0]
#
# Array 9:
# [627, 627, 0]
