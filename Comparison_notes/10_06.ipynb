# %% [markdown]
# # ALB

# %% [markdown]
# ### 1. NORMAL CASES
#
#
# Array 1: Average Resource Utilization
# [70.98, 72.74, 16.05, 60.43, 4651.70]
#
# Array 2: FPS
# [10.06]
#
# Array 3: Overall E2E Latencies
# [46.20, 96.90, 166.01]
#
# Array 4: lane_detection E2E Latencies
# [23.80, 58.50, 125.49]
#
# Array 5: collision_avoidance E2E Latencies
# [29.70, 59.30, 127.19]
#
# Array 6: traffic_sign_detection E2E Latencies
# [82.10, 119.50, 193.46]
#
# Array 7: Onboard Count per Application
# [1092, 1091, 0]
#
# Array 8: Offload Count per Application
# [573, 573, 1661]
#
# Array 9:
# [1665, 4990, 5]
#
#
# ### 2. Under Stress Varying
#
# Array 1: Average Resource Utilization
# [89.18, 90.78, 74.28, 86.31, 9355.81]
#
# Array 2: FPS
# [9.16]
#
# Array 3: Overall E2E Latencies
# [94.50, 185.48, 486.03]
#
# Array 4: lane_detection E2E Latencies
# [94.20, 183.52, 482.32]
#
# Array 5: collision_avoidance E2E Latencies
# [94.50, 184.24, 482.84]
#
# Array 6: traffic_sign_detection E2E Latencies
# [94.80, 187.70, 486.50]
#
# Array 7: Onboard Count per Application
# [14, 14, 0]
#
# Array 8: Offload Count per Application
# [1715, 1715, 1729]
#
# Array 9:
# [1729, 1729, 0]

# %% [markdown]
# # ONBOARD

# %% [markdown]
# ### 1. Normal Cases
#
# Array 1: Average Resource Utilization
# [79.37, 67.46, 22.46, 62.98, 5277.75]
#
# Array 2: FPS
# [9.99]
#
# Array 3: Overall E2E Latencies
# [24.80, 41.40, 103.92]
#
# Array 4: lane_detection E2E Latencies
# [19.30, 30.80, 93.50]
#
# Array 5: collision_avoidance E2E Latencies
# [24.45, 38.64, 102.54]
#
# Array 6: traffic_sign_detection E2E Latencies
# [30.00, 47.00, 111.78]
#
# Array 7: Onboard Count per Application
# [1681, 1680, 1680]
#
# Array 8: Offload Count per Application
# [0, 0, 0]
#
# Array 9: Frame Statistics
# [1681, 1680, 1]
#
#
#
# ### 2. Varying Stress
# Array 1: Average Resource Utilization
# [92.96, 87.92, 5.62, 16.68, 5358.49]
#
# Array 2: FPS
# [2.90]
#
# Array 3: Overall E2E Latencies
# [37.70, 192.79, 1122.23]
#
# Array 4: lane_detection E2E Latencies
# [33.20, 177.65, 812.89]
#
# Array 5: collision_avoidance E2E Latencies
# [37.30, 188.45, 1161.64]
#
# Array 6: traffic_sign_detection E2E Latencies
# [43.20, 202.85, 1163.52]
#
# Array 7: Onboard Count per Application
# [496, 496, 496]
#
# Array 8: Offload Count per Application
# [0, 0, 0]
#
# Array 9:
# [496, 496, 0]

# %% [markdown]
# # OFFBOARD

# %% [markdown]
# ### 1. Normla
#
# Array 1: Average Resource Utilization
# [57.07, 93.55, 96.43, 96.54, 9933.71]
#
# Array 2: FPS
# [9.28]
#
# Array 3: Overall E2E Latencies
# [54.90, 87.10, 235.15]
#
# Array 4: lane_detection E2E Latencies
# [54.60, 86.80, 227.39]
#
# Array 5: collision_avoidance E2E Latencies
# [54.90, 87.10, 227.59]
#
# Array 6: traffic_sign_detection E2E Latencies
# [55.10, 87.30, 227.79]
#
# Array 7: Onboard Count per Application
# [0, 0, 0]
#
# Array 8: Offload Count per Application
# [1671, 1671, 1671]
#
# Array 9:
# [1671, 1671, 0]
#
#
#
#
# ### 2. Under Varying Stress (55% ->30 sec 65% -> 30sec  75% -> 30sec 85% -> 90sec)
#
# Array 1: Average Resource Utilization
# [90.28, 90.67, 67.54, 82.60, 8943.90]
#
# Array 2: FPS
# [9.11]
#
# Array 3: Overall E2E Latencies
# [96.80, 197.15, 532.61]
#
# Array 4: lane_detection E2E Latencies
# [96.40, 196.70, 528.12]
#
# Array 5: collision_avoidance E2E Latencies
# [96.70, 197.18, 532.67]
#
# Array 6: traffic_sign_detection E2E Latencies
# [97.00, 197.38, 532.93]
#
# Array 7: Onboard Count per Application
# [0, 0, 0]
#
# Array 8: Offload Count per Application
# [1662, 1662, 1662]
#
# Array 9:
# [5400, 1662, 3738]
#
#
# ### 3. Network on and off
#
# Array 1: Average Resource Utilization
# [70.40, 91.63, 40.73, 80.54, 6555.60]
#
# Array 2: FPS
# [9.59]
#
# Array 3: Overall E2E Latencies
# [64.70, 150.54, 373.92]
#
# Array 4: lane_detection E2E Latencies
# [64.40, 150.22, 373.32]
#
# Array 5: collision_avoidance E2E Latencies
# [64.70, 150.50, 373.52]
#
# Array 6: traffic_sign_detection E2E Latencies
# [64.90, 150.94, 373.72]
#
# Array 7: Onboard Count per Application
# [0, 0, 0]
#
# Array 8: Offload Count per Application
# [2199, 2199, 2199]
#
# Array 9:
# [2199, 2199, 0]
