# %% [markdown]
# # ALB

# %% [markdown]
# ### 1. NORMAL CASES
#
#
# Array 1: Average Resource Utilization
# [70.98, 72.74, 16.05, 60.43, 4651.70]
#
# Array 2: FPS
# [10.06]
#
# Array 3: Overall E2E Latencies
# [46.20, 96.90, 166.01]
#
# Array 4: lane_detection E2E Latencies
# [23.10, 61.02, 126.72]
#
# Array 5: collision_avoidance E2E Latencies
# [29.95, 61.80, 129.64]
#
# Array 6: traffic_sign_detection E2E Latencies
# [82.10, 119.50, 193.46]
#
# Array 7: Onboard Count per Application
# [1092, 1091, 0]
#
# Array 8: Offload Count per Application
# [573, 573, 1661]
#
# Array 9:
# [1665, 4990, 5]
#
#
# ### 2. Under Stress
#
# Array 1: Average Resource Utilization
# [89.14, 93.66, 53.49, 82.51, 8106.21]
#
# Array 2: FPS
# [7.61]
#
# Array 3: Overall E2E Latencies
# [103.40, 268.80, 3032.66]
#
# Array 4: lane_detection E2E Latencies
# [99.85, 260.16, 3033.46]
#
# Array 5: collision_avoidance E2E Latencies
# [101.15, 265.28, 3033.85]
#
# Array 6: traffic_sign_detection E2E Latencies
# [108.65, 271.76, 2912.39]
#
# Array 7: Onboard Count per Application
# [100, 100, 0]
#
# Array 8: Offload Count per Application
# [1192, 1192, 1288]
