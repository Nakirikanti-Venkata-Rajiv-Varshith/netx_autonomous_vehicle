# %% [markdown]
# # Normal Conditions

# %% [markdown]
# # ALb using If else
#
# array1 = [73.89, 75.97, 13.35, 53.48]
#
# array2 = [41.60, 297.20, 481.36]
#
# array3 = [30.40, 272.62, 498.32]    // collision_avoidance
#
# array4 = [24.50, 168.65, 360.00]    // lane_detection
#
# array5 = [148.00, 376.05, 497.55]   // traffic_sign_detection
#
# array6 = [778, 778, 0]              // onboard counts
#
# array7 = [192, 213, 764]            // offloaded(edge) counts
#
#
#
# # ALB using If else and 3 cloud threads
#
# array1 = [77.33, 76.23, 12.80, 58.88]
#
# array2 = [184.90, 356.12, 672.26]
#
# array3 = [66.60, 373.40, 667.00]     // collision_avoidance
#
# array4 = [57.40, 303.92, 635.48]     // lane_detection
#
# array5 = [221.05, 358.45, 686.66]    // traffic_sign_detection
#
# array6 = [476, 476, 0]               // onboard counts
#
# array7 = [375, 384, 746]             // offloaded(edge) counts
#
#
#
# # ALB using If else and Decison to Send which models need what
#
# array1 = [73.42, 75.35, 17.34, 57.41]
#
# array2 = [36.00, 95.50, 164.64]
#
# array3 = [24.90, 59.20, 148.34]     // collision_avoidance
#
# array4 = [20.00, 58.70, 148.06]     // lane_detection
#
# array5 = [85.00, 109.02, 178.60]    // traffic_sign_detection
#
# array6 = [748, 748, 0]              // onboard counts
#
# array7 = [173, 173, 919]            // offloaded(edge) counts
#
#
# # If lese Model Selection Skip
#
# array1 = [71.15, 72.95, 10.38, 57.85]
#
# array2 = [53.70, 117.16, 206.03]
#
# array3 = [25.95, 85.59, 181.15]     // collision_avoidance
#
# array4 = [20.80, 83.87, 180.78]     // lane_detection
#
# array5 = [83.60, 150.42, 226.60]    // traffic_sign_detection
#
# array6 = [776, 776, 0]              // onboard counts
#
# array7 = [244, 244, 1019]           // offloaded counts
#
#
# # ML fusion Score Based Skip
#
# array1 = [65.49, 68.22, 9.78, 54.40]
#
# array2 = [23.10, 88.90, 161.66]
#
# array3 = [20.90, 34.95, 88.22]      // collision_avoidance
#
# array4 = [17.20, 29.45, 80.70]      // lane_detection
#
# array5 = [81.50, 115.72, 197.20]    // traffic_sign_detection
#
# array6 = [1018, 1018, 0]            // onboard counts
#
# array7 = [0, 0, 1017]               // offloaded(edge) counts
#
#
#
#
# # ALB using Score(mine)
#
# array1 = [80.80, 76.52, 18.19, 53.22]
#
# array2 = [35.10, 158.90, 303.46]
#
# array3 = [29.40, 54.25, 120.01]     // collision_avoidance
#
# array4 = [23.65, 74.89, 280.44]     // lane_detection
#
# array5 = [130.70, 238.22, 373.54]   // traffic_sign_detection
#
# array6 = [594, 549, 0]               // onboard counts
#
# array7 = [0, 39, 559]                // offloaded(edge) counts
#
#
#
# # ALB using Score with 3 clouds(mine)
#
# array1 = [80.55, 75.16, 14.80, 55.77]
#
# array2 = [38.35, 175.20, 306.30]
#
# [collision_avoidance, lane_detection, traffic_sign_detection]
#
# array3 = [31.40, 55.10, 124.00]      // collision_avoidance
#
# array4 = [25.20, 75.40, 287.14]      // lane_detection
#
# array5 = [149.70, 243.71, 380.79]    // traffic_sign_detection
#
# array6 = [902, 825, 0]               // onboard counts
#
# array7 = [0, 73, 838]                // offloaded(edge) counts
#
#
#
#
# # ALB usig Score With Selective Cloud model
#
# array1 = [79.43, 75.14, 18.01, 56.38]
#
# array2 = [32.00, 100.84, 216.37]
#
# array3 = [24.85, 53.84, 110.46]    // collision_avoidance
#
# array4 = [21.35, 63.37, 114.24]    // lane_detection
#
# array5 = [88.90, 157.02, 281.69]   // traffic_sign_detection
#
# array6 = [944, 855, 0]             // onboard counts
#
# array7 = [0, 89, 939]              // offloaded(edge) counts

# %% [markdown]
# # ML BASED NORMAL

# %% [markdown]
# # ITS 60 threshold
#
# array1 = [73.15, 74.20, 15.57, 62.34]
#
# array2 = [68.10, 109.70, 199.41]
#
# array3 = [67.90, 109.60, 199.20]    // collision_avoidance
#
# array4 = [67.00, 109.16, 197.81]    // lane_detection
#
# array5 = [69.10, 110.82, 200.82]    // traffic_sign_detection
#
# array6 = [749, 749, 750]            // onboard counts
#
# array7 = [753, 753, 752]            // offloaded(edge) counts
#
# # ITs also 60 but application prorpity
#
# array1 = [80.42, 68.77, 17.22, 62.28]
#
# array2 = [94.40, 169.12, 274.79]
#
# array3 = [61.40, 119.60, 217.92]    // collision_avoidance
#
# array4 = [86.05, 154.20, 260.31]    // lane_detection
#
# array5 = [129.75, 198.33, 319.35]   // traffic_sign_detection
#
# array6 = [1449, 914, 0]             // onboard counts
#
# array7 = [34, 568, 1482]            // offloaded counts
#
#
#
#
# # ALB using If else and Decison to Send which models need what
#
# array1 = [73.42, 75.35, 17.34, 57.41]
#
# array2 = [36.00, 95.50, 164.64]
#
# array3 = [24.90, 59.20, 148.34]     // collision_avoidance
#
# array4 = [20.00, 58.70, 148.06]     // lane_detection
#
# array5 = [85.00, 109.02, 178.60]    // traffic_sign_detection
#
# array6 = [748, 748, 0]              // onboard counts
#
# array7 = [173, 173, 919]            // offloaded(edge) counts

# %% [markdown]
# # UNder Stress

# %% [markdown]
# # ALB ASelective Model If else
#
# array1 = [89.37, 88.00, 51.56, 82.30]
#
# array2 = [94.70, 197.96, 769.45]
#
# array3 = [92.00, 182.10, 668.36]     // collision_avoidance
#
# array4 = [91.20, 181.90, 663.70]     // lane_detection
#
# array5 = [101.10, 218.44, 801.82]    // traffic_sign_detection
#
# array6 = [183, 183, 0]               // onboard counts
#
# array7 = [959, 959, 1138]            // offloaded(edge) counts
#
# # ALB Selective IF else SKIP Frame
#
# array1 = [95.76, 83.65, 83.85, 86.83]
#
# array2 = [96.50, 151.50, 250.45]
#
# array3 = [96.60, 150.74, 250.38]    // collision_avoidance
#
# array4 = [95.95, 150.02, 250.18]    // lane_detection
#
# array5 = [96.85, 151.95, 250.48]    // traffic_sign_detection
#
# array6 = [18, 18, 0]                // onboard counts
#
# array7 = [1002, 1002, 1020]         // offloaded counts
#
#
#
# # ALB SELECTIVE Models Score based(mine)
#
# array1 = [96.10, 79.79, 69.97, 86.19]
#
# array2 = [99.60, 223.34, 385.36]
#
# array3 = [52.70, 106.13, 199.07]    // collision_avoidance
#
# array4 = [93.20, 201.85, 357.93]    // lane_detection
#
# array5 = [197.70, 309.98, 443.07]   // traffic_sign_detection
#
# array6 = [1131, 617, 20]            // onboard counts
#
# array7 = [0, 495, 1067]             // offloaded counts
#
#
# <!-- # MLK Fusion Score
#
# array1 = [96.66, 81.59, 85.01, 88.57]
#
# array2 = [98.70, 195.00, 360.00]
#
# array3 = [88.90, 153.99, 303.49]    // collision_avoidance
#
# array4 = [102.40, 195.74, 356.52]   // lane_detection
#
# array5 = [109.30, 228.64, 383.60]   // traffic_sign_detection
#
# array6 = [498, 132, 27]             // onboard counts
#
# array7 = [1003, 1360, 1460]         // offloaded counts -->
#
#
# # ALB Selective IF else
#
# array1 = [95.76, 83.65, 83.85, 86.83]
#
# array2 = [96.50, 151.50, 250.45]
#
# array3 = [96.60, 150.74, 250.38]    // collision_avoidance
#
# array4 = [95.95, 150.02, 250.18]    // lane_detection
#
# array5 = [96.85, 151.95, 250.48]    // traffic_sign_detection
#
# array6 = [18, 18, 0]                // onboard counts
#
# array7 = [1002, 1002, 1020]         // offloaded counts
#
#
#
# # ML Fusion
#
#
# array1 = [97.68, 87.64, 86.66, 88.33]
#
# array2 = [83.60, 204.55, 364.21]
#
# array3 = [42.60, 93.10, 207.90]     // collision_avoidance
#
# array4 = [50.15, 176.85, 279.42]    // lane_detection
#
# array5 = [170.70, 255.25, 434.79]   // traffic_sign_detection
#
# array6 = [1008, 712, 0]             // onboard counts
#
# array7 = [0, 296, 1006]             // offloaded(edge) counts
