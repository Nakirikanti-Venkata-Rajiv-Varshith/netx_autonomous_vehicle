# %% [markdown]
# # If else VS Ml Fusion

# %% [markdown]
# ### DETAILS here we are using if else and ml Fusion who have Model section when sending to offload so remeber

# %% [markdown]
# # ALB using If else and Decison to Send which models need what
#
# array1 = [72.94, 66.15, 12.71, 58.44]
#
# array2 = [46.10, 96.10, 183.46]
#
# array3 = [27.65, 61.67, 127.34]     // collision_avoidance
#
# array4 = [21.90, 59.57, 126.56]     // lane_detection
#
# array5 = [84.50, 117.70, 195.46]    // traffic_sign_detection
#
# array6 = [1144, 1144, 0]            // onboard counts
#
# array7 = [383, 383, 1524]           // offloaded(edge) counts
#
#
#
#
# # ALB ML Fusion
#
# array1 = [82.69, 65.97, 19.47, 64.25]
#
# array2 = [33.00, 97.28, 230.30]
#
# array3 = [27.30, 53.69, 117.72]     // collision_avoidance
#
# array4 = [22.00, 48.09, 110.24]     // lane_detection
#
# array5 = [97.50, 154.50, 265.44]    // traffic_sign_detection
#
# array6 = [1555, 1526, 21]           // onboard counts
#
# array7 = [0, 29, 1531]              // offloaded counts
#
#
# # Onboard
#
# array1 = [79.11, 66.33, 22.62, 65.43]
#
# array2 = [25.45, 41.60, 102.42]
#
# array3 = [25.10, 39.20, 102.96]     // collision_avoidance
#
# array4 = [20.00, 31.20, 93.09]      // lane_detection
#
# array5 = [30.90, 48.14, 111.40]     // traffic_sign_detection
#
# array6 = [1612, 1613, 1612]         // onboard counts
#
# array7 = [0, 0, 0]                  // offloaded counts

# %% [markdown]
# ### UNDER STREESS CONDITION

# %% [markdown]
# # ALB ASelective Model If else  New Stress
#
# array1 = [89.37, 88.00, 51.56, 82.30]
#
# array2 = [94.70, 197.96, 769.45]
#
# array3 = [92.00, 182.10, 668.36]     // collision_avoidance
#
# array4 = [91.20, 181.90, 663.70]     // lane_detection
#
# array5 = [101.10, 218.44, 801.82]    // traffic_sign_detection
#
# array6 = [183, 183, 0]               // onboard counts
#
# array7 = [959, 959, 1138]            // offloaded(edge) counts
#
#
# # If lese Under Stress Normal
#
# array1 = [97.08, 89.98, 89.86, 90.47]
#
# array2 = [95.50, 187.76, 356.46]
#
# array3 = [95.50, 187.80, 352.54]    // collision_avoidance
#
# array4 = [95.20, 187.50, 352.31]    // lane_detection
#
# array5 = [95.70, 187.90, 353.97]    // traffic_sign_detection
#
# array6 = [0, 0, 0]                  // onboard counts
#
# array7 = [1473, 1473, 1473]         // offloaded(edge) counts
#
#
# # ML Fusion
#
# array1 = [97.80, 80.24, 84.58, 87.95]
#
# array2 = [126.30, 239.18, 421.70]
#
# array3 = [48.40, 154.96, 271.85]    // collision_avoidance
#
# array4 = [135.30, 234.15, 410.33]   // lane_detection
#
# array5 = [160.90, 293.90, 471.17]   // traffic_sign_detection
#
# array6 = [1236, 351, 3]             // onboard counts
#
# array7 = [267, 1135, 1473]          // offloaded(edge) counts
#
#
# # ML Fusion N stress
#
# array1 = [94.10, 87.10, 54.62, 80.75]
#
# array2 = [99.60, 255.32, 635.17]
#
# array3 = [66.75, 159.27, 451.84]    // collision_avoidance
#
# array4 = [91.15, 196.36, 510.64]    // lane_detection
#
# array5 = [156.40, 332.26, 817.54]   // traffic_sign_detection
#
# array6 = [742, 522, 0]              // onboard counts
#
# array7 = [300, 518, 1021]           // offloaded counts
#
#
#
#
# # Onboard Under normal Stress
#
# array1 = [98.15, 79.23, 81.28, 87.53]
#
# array2 = [40.80, 88.71, 220.01]
#
# array3 = [40.10, 87.50, 216.65]     // collision_avoidance
#
# array4 = [30.90, 76.20, 200.11]     // lane_detection
#
# array5 = [50.55, 99.80, 230.81]     // traffic_sign_detection
#
# array6 = [1758, 1758, 1758]         // onboard counts
#
# array7 = [0, 0, 0]                  // offloaded counts
#
#
#
# # Onboard Under N Stress
#
# array1 = [93.98, 87.68, 55.55, 82.85]
#           // [cpu, ram, gpu_overall, gpu_when_active]
#
# array2 = [39.40, 93.84, 417.52]
#           // overall latency [p50, p90, p99] ms
#
# array3 = [39.10, 93.42, 418.16]
#           // collision_avoidance [p50, p90, p99] ms
#
# array4 = [28.90, 79.84, 382.71]
#           // lane_detection [p50, p90, p99] ms
#
# array5 = [49.20, 103.58, 423.96]
#           // traffic_sign_detection [p50, p90, p99] ms
#
# array6 = [1602, 1602, 1602]
#           // onboard counts
#           // [collision_avoidance, lane_detection, traffic_sign_detection]
#
# array7 = [0, 0, 0]
#           // offloaded counts
#           // [collision_avoidance, lane_detection, traffic_sign_detection]
